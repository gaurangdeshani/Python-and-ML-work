# %% [markdown]
# # step 1.0
# ## In ML is data preprocessing
# ##     Importing the libraries
#
# ###         pandas for importing dataset and manging the dataset
# ###         matplotlib.pyplot for graphical representation of data
# ###         numpy for mathematical operation on data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as ply

# %% [markdown]
# # step 1.1
# ## Importing the dataset + managing the datasets
# ## For importing pandas will be usefull

# %%
dataset = pd.read_csv("C:\\Users\\Gaurang\\Desktop\\year2017.csv")
dataset
# Out:
#        Year  Month  Day                           Country  \
# 0      2017      1    2                       Afghanistan
# 1      2017      1    3                             Sudan
# 2      2017      1    1  Democratic Republic of the Congo
# 3      2017      1    1  Democratic Republic of the Congo
# 4      2017      1    1                            Turkey
# ...     ...    ...  ...                               ...
# 10895  2017     12   31                           Somalia
# 10896  2017     12   31                             Syria
# 10897  2017     12   31                       Philippines
# 10898  2017     12   31                             India
# 10899  2017     12   31                       Philippines
#
#                            Region           city   latitude   longitude  \
# 0                      South Asia     Takhta Pul  31.320556   65.961111
# 1              Sub-Saharan Africa        Fantaga  12.921007   24.318324
# ...

# %%
X = dataset.iloc[: , [0,1,2,3,10]]
X
# Out:
#        Year  Month  Day                           Country  Wounded
# 0      2017      1    2                       Afghanistan      0.0
# 1      2017      1    3                             Sudan      0.0
# 2      2017      1    1  Democratic Republic of the Congo      0.0
# 3      2017      1    1  Democratic Republic of the Congo      0.0
# 4      2017      1    1                            Turkey     69.0
# ...     ...    ...  ...                               ...      ...
# 10895  2017     12   31                           Somalia      2.0
# 10896  2017     12   31                             Syria      7.0
# 10897  2017     12   31                       Philippines      0.0
# 10898  2017     12   31                             India      0.0
# 10899  2017     12   31                       Philippines      0.0
#
# [10900 rows x 5 columns]
